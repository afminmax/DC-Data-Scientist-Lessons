# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# ## Stock Visualization

# %%
df = pd.read_csv('4stocks.csv')

# %%
df
# Out:
#            Date         IBM         GOOG        AAPL         AMZN
# 0    12/31/2018  109.748711  1035.609985  155.871613  1501.969971
# 1      1/2/2019  111.235573  1045.849976  156.049484  1539.130005
# 2      1/3/2019  109.014923  1016.059998  140.505798  1500.280029
# 3      1/4/2019  113.272789  1070.709961  146.503891  1575.390015
# 4      1/7/2019  114.074165  1068.390015  146.177811  1629.510010
# ..          ...         ...          ...         ...          ...
# 180   9/18/2019  142.220001  1232.410034  222.770004  1817.459961
# 181   9/19/2019  142.970001  1238.709961  220.960007  1821.500000
# 182   9/20/2019  141.880005  1229.930054  217.729996  1794.160034
# 183   9/23/2019  142.070007  1234.030029  218.720001  1785.300049
# 184   9/24/2019  141.679993  1218.760010  217.679993  1741.609985
#
# [185 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
# Date    185 non-null object
# IBM     185 non-null float64
# GOOG    185 non-null float64
# AAPL    185 non-null float64
# AMZN    185 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %%
df.shape
# Out:
# (185, 5)

# %%
df.describe()
# Out:
#               IBM         GOOG        AAPL         AMZN
# count  185.000000   185.000000  185.000000   185.000000
# mean   134.811118  1151.256704  189.717824  1795.229082
# std      7.566215    57.345894   19.479856   117.669485
# min    109.014923  1016.059998  140.505798  1500.280029
# 25%    131.919998  1110.750000  174.194778  1692.430054
# 50%    135.563431  1151.290039  194.829758  1816.119995
# 75%    139.091141  1193.989990  203.636292  1878.270020
# max    149.597351  1287.579956  223.589996  2020.989990

# %%
y_columns = ['IBM','GOOG','AAPL','AMZN']

# %%
#df.plot(figsize=(10,5))
df.plot(x='Date', y=y_columns, figsize=(13,5))
#df.plot(figsize=(10,5))
plt.title('Tech Titans in 2019 YTD')
plt.xlabel('Day')
plt.ylabel('Price USD')
plt.show()

# %% [markdown]
# ## Mile Per Gallon Visualization

# %%
mpgdf = pd.read_csv('auto-mpg.csv')

# %%
mpgdf
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70      US
# 1    15.0    8  350.0  165    3693   11.5  70      US
# 2    18.0    8  318.0  150    3436   11.0  70      US
# 3    16.0    8  304.0  150    3433   12.0  70      US
# 4    17.0    8  302.0  140    3449   10.5  70      US
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82      US
# 388  44.0    4   97.0   52    2130   24.6  82  Europe
# 389  32.0    4  135.0   84    2295   11.6  82      US
# 390  28.0    4  120.0   79    2625   18.6  82      US
# 391  31.0    4  119.0   82    2720   19.4  82      US
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
mpgdf.describe()
# Out:
#               mpg         cyl       displ          hp       weight  \
# count  392.000000  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184
# std      7.805007    1.705783  104.644004   38.491160   849.402560
# min      9.000000    3.000000   68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#             accel          yr
# count  392.000000  392.000000
# mean    15.541327   75.979592
# std      2.758864    3.683737
# min      8.000000   70.000000
# 25%     13.775000   73.000000
# 50%     15.500000   76.000000
# 75%     17.025000   79.000000
# max     24.800000   82.000000

# %%
mpgdf.plot(kind='scatter', x='hp', y='mpg')
plt.title('Fuel efficiency vs Horse-power')
plt.xlabel('Horse-Power')
plt.ylabel('Miles Per Gallon')
# Out:
# Text(0, 0.5, 'Miles Per Gallon')

# %% [markdown]
# ## Box Plots

# %%
mpg_columns = ['weight','mpg']

# %%
mpgdf.plot(subplots=True, figsize=(13,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F51870CC8>,
# ...
#       dtype=object)

# %%
mpgdf[mpg_columns].plot(subplots=True, figsize=(13,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F52870C88>,
# ...
#       dtype=object)

# %%
mpgdf[mpg_columns].plot(kind='box', subplots=True, figsize=(13,10))
# Out:
# weight       AxesSubplot(0.125,0.125;0.352273x0.755)
# mpg       AxesSubplot(0.547727,0.125;0.352273x0.755)
# dtype: object
